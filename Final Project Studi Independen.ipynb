# %%
import json
import csv

from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
df=pd.read_json('/content/gdrive/MyDrive/Colab Notebooks/transactions.json')
df
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#         {"accountNumber": "733493772"   "customerId": "733493772"  \
# 0       {"accountNumber": "733493772"   "customerId": "733493772"
# 1       {"accountNumber": "733493772"   "customerId": "733493772"
# 2       {"accountNumber": "733493772"   "customerId": "733493772"
# 3       {"accountNumber": "733493772"   "customerId": "733493772"
# 4       {"accountNumber": "733493772"   "customerId": "733493772"
# ...                               ...                         ...
# 641908  {"accountNumber": "186770399"   "customerId": "186770399"
# 641909  {"accountNumber": "186770399"   "customerId": "186770399"
# 641910  {"accountNumber": "186770399"   "customerId": "186770399"
# 641911  {"accountNumber": "186770399"   "customerId": "186770399"
# 641912  {"accountNumber": "186770399"   "customerId": "186770399"
#
#          "creditLimit": 5000.0    "availableMoney": 5000.0  \
# 0        "creditLimit": 5000.0   "availableMoney": 4888.67
# 1        "creditLimit": 5000.0   "availableMoney": 4863.92
# 2        "creditLimit": 5000.0   "availableMoney": 4676.52
# 3        "creditLimit": 5000.0   "availableMoney": 4449.18
# 4        "creditLimit": 5000.0   "availableMoney": 4449.18
# ...                        ...                         ...
# 641908   "creditLimit": 7500.0   "availableMoney": 2574.02
# 641909   "creditLimit": 7500.0   "availableMoney": 2568.65
# 641910   "creditLimit": 7500.0   "availableMoney": 2344.95
# 641911   "creditLimit": 7500.0   "availableMoney": 2206.53
# 641912   "creditLimit": 7500.0   "availableMoney": 2190.22
#
#         "transactionDateTime": "2016-01-08T19:04:50"  \
# 0                           "currentBalance": 111.33
# 1                           "currentBalance": 136.08
# 2                           "currentBalance": 323.48
# 3                           "currentBalance": 550.82
# 4                           "currentBalance": 550.82
# ...                                              ...
# 641908                     "currentBalance": 4925.98
# 641909                     "currentBalance": 4931.35
# 641910                     "currentBalance": 5155.05
# 641911                     "currentBalance": 5293.47
# 641912                     "currentBalance": 5309.78
#
#                           "transactionAmount": 111.33  \
# 0        "transactionDateTime": "2016-01-09T22:32:39"
# 1        "transactionDateTime": "2016-01-11T13:36:55"
# 2        "transactionDateTime": "2016-01-11T22:47:46"
# 3        "transactionDateTime": "2016-01-16T01:41:11"
# 4        "transactionDateTime": "2016-01-16T21:35:27"
# ...                                               ...
# 641908   "transactionDateTime": "2016-12-04T12:29:21"
# 641909   "transactionDateTime": "2016-12-09T04:20:35"
# 641910   "transactionDateTime": "2016-12-16T07:58:23"
# 641911   "transactionDateTime": "2016-12-19T02:30:35"
# 641912   "transactionDateTime": "2016-12-28T11:14:14"
#
#               "merchantName": "Lyft"  \
# 0         "transactionAmount": 24.75
# 1         "transactionAmount": 187.4
# 2        "transactionAmount": 227.34
# 3             "merchantName": "Lyft"
# 4           "transactionAmount": 9.8
# ...                              ...
# 641908     "transactionAmount": 5.37
# 641909    "transactionAmount": 223.7
# 641910   "transactionAmount": 138.42
# 641911    "transactionAmount": 16.31
# 641912    "transactionAmount": 32.53
#
#                                  "acqCountry": "US"  \
# 0                            "merchantName": "Uber"
# 1                            "merchantName": "Lyft"
# 2                            "merchantName": "Lyft"
# 3                                "acqCountry": "US"
# 4                    "merchantName": "Fresh eCards"
# ...                                             ...
# 641908               "merchantName": "Apple iTunes"
# 641909       "merchantName": "Blue Mountain eCards"
# 641910              "merchantName": "Fresh Flowers"
# 641911                    "merchantName": "abc.com"
# 641912   "merchantName": "Next Day Online Services"
#
#          "merchantCountryCode": "US"          "posEntryMode": "05"  ...  \
# 0                 "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 1                 "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 2                 "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 3        "merchantCountryCode": "US"          "posEntryMode": "02"  ...
# 4                 "acqCountry": "US"   "merchantCountryCode": "US"  ...
# ...                              ...                           ...  ...
# 641908            "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 641909            "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 641910            "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 641911            "acqCountry": "US"   "merchantCountryCode": "US"  ...
# 641912            "acqCountry": "US"   "merchantCountryCode": "US"  ...
#
#                        "isFraud": true           "echoBuffer": ""  \
# 0        "transactionType": "PURCHASE"           "echoBuffer": ""
# 1        "transactionType": "PURCHASE"           "echoBuffer": ""
# 2        "transactionType": "PURCHASE"            "isFraud": true
# 3                     "echoBuffer": ""   "transactionAmount": 0.0
# 4        "transactionType": "PURCHASE"           "echoBuffer": ""
# ...                                ...                        ...
# 641908   "transactionType": "PURCHASE"           "echoBuffer": ""
# 641909   "transactionType": "PURCHASE"           "echoBuffer": ""
# 641910   "transactionType": "PURCHASE"           "echoBuffer": ""
# 641911   "transactionType": "PURCHASE"           "echoBuffer": ""
# 641912   "transactionType": "PURCHASE"           "echoBuffer": ""
#
#         "currentBalance": 0.0    "merchantCity": ""   "merchantState": ""  \
# 0          "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 1          "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 2            "echoBuffer": ""    "merchantCity": ""   "merchantState": ""
# 3          "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 4          "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# ...                       ...                   ...                   ...
# 641908     "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 641909     "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 641910     "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 641911     "merchantCity": ""   "merchantState": ""     "merchantZip": ""
# 641912     "merchantCity": ""   "merchantState": ""     "merchantZip": ""
#
#             "merchantZip": ""   "cardPresent": false      "posOnPremises": ""  \
# 0        "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 1        "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 2           "merchantZip": ""   "cardPresent": false      "posOnPremises": ""
# 3        "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 4        "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# ...                       ...                    ...                      ...
# 641908   "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 641909   "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 641910   "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 641911   "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
# 641912   "cardPresent": false    "posOnPremises": ""   "recurringAuthInd": ""
#
#                     "recurringAuthInd": ""  \
# 0        "expirationDateKeyInMatch": false
# 1        "expirationDateKeyInMatch": false
# 2                   "recurringAuthInd": ""
# 3        "expirationDateKeyInMatch": false
# 4        "expirationDateKeyInMatch": false
# ...                                    ...
# 641908   "expirationDateKeyInMatch": false
# 641909   "expirationDateKeyInMatch": false
# 641910   "expirationDateKeyInMatch": false
# 641911   "expirationDateKeyInMatch": false
# 641912   "expirationDateKeyInMatch": false
#
#          "expirationDateKeyInMatch": false}
# 0                         "isFraud": false}
# 1                         "isFraud": false}
# 2        "expirationDateKeyInMatch": false}
# 3                         "isFraud": false}
# 4                         "isFraud": false}
# ...                                     ...
# 641908                    "isFraud": false}
# 641909                    "isFraud": false}
# 641910                    "isFraud": false}
# 641911                    "isFraud": false}
# 641912                    "isFraud": false}
#
# [641913 rows x 29 columns]

# %%
import json
import csv

from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
df=pd.read_json('/content/gdrive/MyDrive/Colab Notebooks/transactions.json', lines=True)
df

# %%
df.columns
# Out:
# Index(['accountNumber', 'customerId', 'creditLimit', 'availableMoney',
#        'transactionDateTime', 'transactionAmount', 'merchantName',
#        'acqCountry', 'merchantCountryCode', 'posEntryMode', 'posConditionCode',
#        'merchantCategoryCode', 'currentExpDate', 'accountOpenDate',
#        'dateOfLastAddressChange', 'cardCVV', 'enteredCVV', 'cardLast4Digits',
#        'transactionType', 'isFraud', 'echoBuffer', 'currentBalance',
#        'merchantCity', 'merchantState', 'merchantZip', 'cardPresent',
#        'posOnPremises', 'recurringAuthInd', 'expirationDateKeyInMatch'],
#       dtype='object')

# %%
df.describe()
# Out:
#        accountNumber    customerId    creditLimit  availableMoney  \
# count   6.419140e+05  6.419140e+05  641914.000000   641914.000000
# mean    5.547701e+08  5.547701e+08   10697.210608     6652.828573
# std     2.546884e+08  2.546884e+08   11460.359133     9227.132275
# min     1.005471e+08  1.005471e+08     250.000000    -1244.930000
# 25%     3.223192e+08  3.223192e+08    5000.000000     1114.970000
# 50%     5.438879e+08  5.438879e+08    7500.000000     3578.165000
# 75%     7.862277e+08  7.862277e+08   15000.000000     8169.185000
# max     9.999853e+08  9.999853e+08   50000.000000    50000.000000
#
#        transactionAmount        cardCVV     enteredCVV  cardLast4Digits  \
# count      641914.000000  641914.000000  641914.000000    641914.000000
# mean          135.162497     557.199927     556.775160      4886.184043
# std           147.053302     257.326204     257.402639      2859.053679
# min             0.000000     100.000000       1.000000         0.000000
# 25%            32.320000     334.000000     333.000000      2364.000000
# 50%            85.800000     581.000000     580.000000      4873.000000
# 75%           189.030000     762.000000     761.000000      7267.000000
# max          1825.250000     998.000000     998.000000      9998.000000
#
#        currentBalance
# count   641914.000000
# mean      4044.382035
# std       5945.510224
# min          0.000000
# 25%        502.442500
# 50%       2151.860000
# 75%       5005.890000
# max      47496.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641914 entries, 0 to 641913
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             641914 non-null  int64
#  1   customerId                641914 non-null  int64
#  2   creditLimit               641914 non-null  int64
#  3   availableMoney            641914 non-null  float64
#  4   transactionDateTime       641914 non-null  object
#  5   transactionAmount         641914 non-null  float64
#  6   merchantName              641914 non-null  object
#  7   acqCountry                641914 non-null  object
#  8   merchantCountryCode       641914 non-null  object
#  9   posEntryMode              641914 non-null  object
#  10  posConditionCode          641914 non-null  object
#  11  merchantCategoryCode      641914 non-null  object
#  12  currentExpDate            641914 non-null  object
#  13  accountOpenDate           641914 non-null  object
#  14  dateOfLastAddressChange   641914 non-null  object
#  15  cardCVV                   641914 non-null  int64
#  16  enteredCVV                641914 non-null  int64
#  17  cardLast4Digits           641914 non-null  int64
#  18  transactionType           641914 non-null  object
#  19  isFraud                   641914 non-null  bool
#  20  echoBuffer                641914 non-null  object
#  21  currentBalance            641914 non-null  float64
#  22  merchantCity              641914 non-null  object
#  23  merchantState             641914 non-null  object
#  24  merchantZip               641914 non-null  object
#  25  cardPresent               641914 non-null  bool
#  26  posOnPremises             641914 non-null  object
#  27  recurringAuthInd          641914 non-null  object
#  28  expirationDateKeyInMatch  641914 non-null  bool
# dtypes: bool(3), float64(3), int64(6), object(17)
# memory usage: 129.2+ MB

# %%
df.isnull().sum()
# Out:
# accountNumber               0
# customerId                  0
# creditLimit                 0
# availableMoney              0
# transactionDateTime         0
# transactionAmount           0
# merchantName                0
# acqCountry                  0
# merchantCountryCode         0
# posEntryMode                0
# posConditionCode            0
# merchantCategoryCode        0
# currentExpDate              0
# accountOpenDate             0
# dateOfLastAddressChange     0
# cardCVV                     0
# enteredCVV                  0
# cardLast4Digits             0
# transactionType             0
# isFraud                     0
# echoBuffer                  0
# currentBalance              0
# merchantCity                0
# merchantState               0
# merchantZip                 0
# cardPresent                 0
# posOnPremises               0
# recurringAuthInd            0
# expirationDateKeyInMatch    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# accountNumber               0
# customerId                  0
# creditLimit                 0
# availableMoney              0
# transactionDateTime         0
# transactionAmount           0
# merchantName                0
# acqCountry                  0
# merchantCountryCode         0
# posEntryMode                0
# posConditionCode            0
# merchantCategoryCode        0
# currentExpDate              0
# accountOpenDate             0
# dateOfLastAddressChange     0
# cardCVV                     0
# enteredCVV                  0
# cardLast4Digits             0
# transactionType             0
# echoBuffer                  0
# currentBalance              0
# merchantCity                0
# merchantState               0
# merchantZip                 0
# cardPresent                 0
# posOnPremises               0
# recurringAuthInd            0
# expirationDateKeyInMatch    0
# dtype: int64

# %%
df.dtypes
# Out:
# accountNumber                 int64
# customerId                    int64
# creditLimit                   int64
# availableMoney              float64
# transactionDateTime          object
# transactionAmount           float64
# merchantName                 object
# acqCountry                   object
# merchantCountryCode          object
# posEntryMode                 object
# posConditionCode             object
# merchantCategoryCode         object
# currentExpDate               object
# accountOpenDate              object
# dateOfLastAddressChange      object
# cardCVV                       int64
# enteredCVV                    int64
# cardLast4Digits               int64
# transactionType              object
# echoBuffer                   object
# currentBalance              float64
# merchantCity                 object
# merchantState                object
# merchantZip                  object
# cardPresent                    bool
# posOnPremises                object
# recurringAuthInd             object
# expirationDateKeyInMatch       bool
# dtype: object

# %%
df=df.drop(columns=['isFraud'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641914 entries, 0 to 641913
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             641914 non-null  int64
#  1   customerId                641914 non-null  int64
#  2   creditLimit               641914 non-null  int64
#  3   availableMoney            641914 non-null  float64
#  4   transactionDateTime       641914 non-null  object
#  5   transactionAmount         641914 non-null  float64
#  6   merchantName              641914 non-null  object
#  7   acqCountry                641914 non-null  object
#  8   merchantCountryCode       641914 non-null  object
#  9   posEntryMode              641914 non-null  object
#  10  posConditionCode          641914 non-null  object
#  11  merchantCategoryCode      641914 non-null  object
#  12  currentExpDate            641914 non-null  object
#  13  accountOpenDate           641914 non-null  object
#  14  dateOfLastAddressChange   641914 non-null  object
#  15  cardCVV                   641914 non-null  int64
#  16  enteredCVV                641914 non-null  int64
#  17  cardLast4Digits           641914 non-null  int64
#  18  transactionType           641914 non-null  object
#  19  echoBuffer                641914 non-null  object
#  20  currentBalance            641914 non-null  float64
#  21  merchantCity              641914 non-null  object
#  22  merchantState             641914 non-null  object
#  23  merchantZip               641914 non-null  object
#  24  cardPresent               641914 non-null  bool
#  25  posOnPremises             641914 non-null  object
#  26  recurringAuthInd          641914 non-null  object
#  27  expirationDateKeyInMatch  641914 non-null  bool
# dtypes: bool(2), float64(3), int64(6), object(17)
# memory usage: 128.6+ MB

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_data.head(20)
# Out:
#                          Total  Percent
# accountNumber                0      0.0
# customerId                   0      0.0
# recurringAuthInd             0      0.0
# posOnPremises                0      0.0
# cardPresent                  0      0.0
# merchantZip                  0      0.0
# merchantState                0      0.0
# merchantCity                 0      0.0
# currentBalance               0      0.0
# echoBuffer                   0      0.0
# transactionType              0      0.0
# cardLast4Digits              0      0.0
# enteredCVV                   0      0.0
# cardCVV                      0      0.0
# dateOfLastAddressChange      0      0.0
# accountOpenDate              0      0.0
# currentExpDate               0      0.0
# merchantCategoryCode         0      0.0
# posConditionCode             0      0.0
# posEntryMode                 0      0.0
